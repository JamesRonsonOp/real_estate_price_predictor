# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# # Cleaning Training CSV
#
# * This notebook takes in an initially cleaned training data csv and a raw test data csv and cleans them to match, dummifies them and cleans them to match once again.

# %% [markdown]
# Read in initial cleaning csv

# %%
ames = pd.read_csv('/Users/jamesopacich/Documents/dsi/projects/project_2/attempt_1/datasets/ames_ic.csv' )

# %%
ames.head()
# Out:
#    ms_subclass ms_zoning  lot_frontage  lot_area lot_config neighborhood  \
# 0           60        RL       69.0552     13517    CulDSac       Sawyer
# 1           60        RL       43.0000     11492    CulDSac      SawyerW
# 2           20        RL       68.0000      7922     Inside        NAmes
# 3           60        RL       73.0000      9802     Inside       Timber
# 4           50        RL       82.0000     14235     Inside      SawyerW
#
#   condition_1 condition_2 bldg_type house_style  ...  3ssn_porch  \
# 0        RRAe        Norm      1Fam      2Story  ...           0
# 1        Norm        Norm      1Fam      2Story  ...           0
# 2        Norm        Norm      1Fam      1Story  ...           0
# 3        Norm        Norm      1Fam      2Story  ...           0
# 4        Norm        Norm      1Fam      1.5Fin  ...           0
#
#    screen_porch  pool_area  misc_val mo_sold yr_sold  sale_type saleprice  \
# 0             0          0         0       3    2010        WD     130500
# 1             0          0         0       4    2009        WD     220000
# 2             0          0         0       1    2010        WD     109000
# 3             0          0         0       4    2010        WD     174000
# 4             0          0         0       3    2010        WD     138500
#
#    ttl_sf ttl_bath
# 0  2204.0      2.5
# 1  3035.0      3.5
# 2  2114.0      2.0
# 3  1828.0      2.5
# 4  2121.0      2.0
#
# [5 rows x 52 columns]

# %%
ames.shape
# Out:
# (2051, 52)

# %%
ames.columns
# Out:
# Index(['ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area', 'lot_config',
#        'neighborhood', 'condition_1', 'condition_2', 'bldg_type',
#        'house_style', 'overall_qual', 'overall_cond', 'year_built',
#        'year_remod/add', 'exterior_1st', 'mas_vnr_type', 'mas_vnr_area',
#        'exter_qual', 'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond',
#        'bsmt_exposure', 'bsmtfin_type_1', 'heating', 'heating_qc',
#        'central_air', 'electrical', 'bedroom_abvgr', 'kitchen_abvgr',
#        'kitchen_qual', 'totrms_abvgrd', 'functional', 'fireplaces',
#        'garage_type', 'garage_yr_blt', 'garage_finish', 'garage_cars',
#        'paved_drive', 'wood_deck_sf', 'open_porch_sf', 'enclosed_porch',
#        '3ssn_porch', 'screen_porch', 'pool_area', 'misc_val', 'mo_sold',
#        'yr_sold', 'sale_type', 'saleprice', 'ttl_sf', 'ttl_bath'],
#       dtype='object')

# %%
# dropping total rooms above ground because it overlaps with total bedrooms and kitchens
ames.drop(columns = 'totrms_abvgrd', inplace = True)

# %%
pool = ames[ames['pool_area'] > 0]

# %%
pool
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area lot_config neighborhood  \
# 52             60        RL       80.0000     16692     Inside       NWAmes
# 657            80        RL       76.0000      9880     Inside      Mitchel
# 761            80        RL      100.0000     14330     Corner      Veenker
# 952            20        RL       70.0000     18044    CulDSac      Crawfor
# 960            60        RL      313.0000     63887     Corner      Edwards
# 1130           20        RL       78.0000     10140     Inside       NWAmes
# 1249           80        RL       69.0552     19690    CulDSac      Edwards
# 1635           20        RL       75.0000      9532     Inside        NAmes
# 1875           20        RL      200.0000     43500     Inside      Mitchel
#
#      condition_1 condition_2 bldg_type house_style  ...  3ssn_porch  \
# 52          RRAn        Norm      1Fam      2Story  ...           0
# 657         Norm        Norm      1Fam        SLvl  ...           0
# 761         Norm        Norm      1Fam        SLvl  ...           0
# 952         Norm        Norm      1Fam      1Story  ...           0
# 960        Feedr        Norm      1Fam      2Story  ...           0
# 1130        Norm        Norm      1Fam      1Story  ...           0
# 1249        Norm        Norm      1Fam        SLvl  ...           0
# 1635        Norm        Norm      1Fam      1Story  ...           0
# 1875      Artery        Norm      1Fam      1Story  ...           0
#
#       screen_porch  pool_area  misc_val mo_sold yr_sold  sale_type saleprice  \
# 52             440        519      2000       7    2006        WD     250000
# 657              0        576         0       7    2008        WD     171000
# 761              0        800         0       1    2006        WD     260000
# 952              0        228         0       8    2007        WD     315000
# 960              0        480         0       1    2008        New    160000
# 1130             0        648         0       1    2006        WD     181000
# 1249             0        738         0       8    2006        WD     274970
# 1635             0        368         0       2    2007        WD     153000
# 1875             0        561         0       6    2007        WD     130000
#
#        ttl_sf ttl_bath
# 52     4176.0      4.5
# 657    2214.0      2.0
# 761    4394.0      4.0
# 952    3005.0      2.5
# 960   11752.0      4.5
# 1130   2349.0      2.5
# 1249   2898.0      2.0
# 1635   2752.0      2.0
# 1875   2034.0      1.0
#
# [9 rows x 51 columns]

# %%
# dropping pool area because there are less than 20 values for pools
ames.drop(columns = 'pool_area', inplace = True )

# %%
# create a df with huge houses
big_houses = ames[ames['ttl_sf'] > 5000]

# %%
# a couple of over 10,000ft homes. I will look into eliminating these outliers. 
big_houses.head()
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area lot_config neighborhood  \
# 30             20        RL       80.0000      9600     Inside       NWAmes
# 328            20        RL       69.0552     12692     Inside      NoRidge
# 960            60        RL      313.0000     63887     Corner      Edwards
# 1117           20        RL       69.0552     11400     Inside      NoRidge
# 1164           20        RL      105.0000     15431     Inside      NridgHt
#
#      condition_1 condition_2 bldg_type house_style  ...  enclosed_porch  \
# 30          PosN        Norm      1Fam      1Story  ...               0
# 328         Norm        Norm      1Fam      1Story  ...             291
# 960        Feedr        Norm      1Fam      2Story  ...               0
# 1117        Norm        Norm      1Fam      1Story  ...               0
# 1164        Norm        Norm      1Fam      1Story  ...               0
#
#       3ssn_porch  screen_porch  misc_val mo_sold yr_sold  sale_type saleprice  \
# 30             0             0         0       7    2009        WD     278000
# 328            0             0         0       5    2007        WD     430000
# 960            0             0         0       1    2008        New    160000
# 1117           0             0         0       3    2007        WD     466500
# 1164           0           170         0       4    2009        WD     555000
#
#        ttl_sf ttl_bath
# 30     5048.0      3.5
# 328    6428.0      4.0
# 960   11752.0      4.5
# 1117   5266.0      3.5
# 1164   5496.0      3.0
#
# [5 rows x 50 columns]

# %%
big_lots_std =  (3 * ames['lot_area'].std()) + ames['lot_area'].mean()
big_lots_std
# Out:
# 30292.67491961595

# %%
ames[ames['lot_area'] > big_lots_std]
# Out:
#       ms_subclass ms_zoning  lot_frontage  lot_area lot_config neighborhood  \
# 24            190        RL      100.0000     34650     Inside      Gilbert
# 108            20        RL       69.0552     39384    CulDSac        NAmes
# 337           190        RL       69.0552     32463     Inside      Mitchel
# 441           190        RL      195.0000     41600        FR2      Gilbert
# 471            50        RL       69.0552    159000    CulDSac      ClearCr
# 616            20        RL      123.0000     47007     Inside      Edwards
# 635            20   A (agr)      125.0000     31250     Inside      Mitchel
# 694            20        RL       69.0552    115149    CulDSac      ClearCr
# 745            20        RL       69.0552     57200     Inside       Timber
# 823            60        RL       47.0000     53504    CulDSac      StoneBr
# 841            20        RL       73.0000     39104    CulDSac      ClearCr
# 913            20        RL       69.0552     32668    CulDSac      Crawfor
# 960            60        RL      313.0000     63887     Corner      Edwards
# 1052           20        RL       69.0552     53227    CulDSac      ClearCr
# 1080           20        RL      141.0000     31770     Corner        NAmes
# 1167           20        RL       69.0552     47280     Inside      Gilbert
# 1542           60        RL       52.0000     46589    CulDSac      NoRidge
# 1571           20        RL       68.0000     50271     Inside      Veenker
# 1701           50        RM       90.0000     33120     Inside      OldTown
# 1726           20        RL       69.0552     50102     Inside       Timber
# 1843           60        RL       69.0552     53107     Corner      ClearCr
# 1854           20        RL       62.0000     70761     Inside      ClearCr
# 1875           20        RL      200.0000     43500     Inside      Mitchel
# 1885           20        RL      128.0000     39290     Inside      Edwards
# 1964           20        RL       52.0000     51974    CulDSac      StoneBr
#
#      condition_1 condition_2 bldg_type house_style  ...  enclosed_porch  \
# 24          Norm        Norm    2fmCon      1Story  ...               0
# 108         Norm        Norm      1Fam      1Story  ...               0
# 337         Norm        Norm    2fmCon      1Story  ...               0
# 441         Norm        Norm    2fmCon      1Story  ...               0
# 471         Norm        Norm      1Fam      1.5Fin  ...               0
# 616         Norm        Norm      1Fam      1Story  ...               0
# 635       Artery        Norm      1Fam      1Story  ...             135
# 694         Norm        Norm      1Fam      1Story  ...               0
# 745         Norm        Norm      1Fam      1Story  ...              50
# 823         Norm        Norm      1Fam      2Story  ...               0
# 841         Norm        Norm      1Fam      1Story  ...               0
# 913         Norm        Norm      1Fam      1Story  ...             200
# 960        Feedr        Norm      1Fam      2Story  ...               0
# 1052        Norm        Norm      1Fam      1Story  ...               0
# 1080        Norm        Norm      1Fam      1Story  ...               0
# 1167        Norm        Norm      1Fam      1Story  ...             180
# 1542        Norm        Norm      1Fam      2Story  ...               0
# 1571        Norm        Norm      1Fam      1Story  ...               0
# 1701        RRAn       Feedr      1Fam      1.5Fin  ...               0
# 1726        Norm        Norm      1Fam      1Story  ...               0
# 1843       Feedr        Norm      1Fam      2Story  ...               0
# 1854        Norm        Norm      1Fam      1Story  ...               0
# 1875      Artery        Norm      1Fam      1Story  ...               0
# 1885        Norm        Norm      1Fam      1Story  ...               0
# 1964        PosN        Norm      1Fam      1Story  ...               0
#
#       3ssn_porch  screen_porch  misc_val mo_sold yr_sold  sale_type saleprice  \
# 24             0             0         0       1    2006        WD     145000
# 108            0             0         0      10    2006        WD     252000
# 337            0             0         0       3    2007        WD     168000
# 441            0             0         0      11    2007        WD     155000
# 471            0             0       500       6    2007        WD     277000
# 616            0             0         0       7    2008        WD     284700
# 635            0             0         0       5    2006        WD      81500
# 694            0             0         0       6    2007        WD     302000
# 745            0             0         0       6    2010        WD     160000
# 823            0           210         0       6    2010        WD     538000
# 841            0             0         0       4    2008        WD     241500
# 913            0             0         0       3    2007        WD     200624
# 960            0             0         0       1    2008        New    160000
# 1052           0             0         0       3    2008        WD     256000
# 1080           0             0         0       5    2010        WD     215000
# 1167           0             0         0       7    2008        WD     133000
# 1542           0             0         0       7    2009        WD     402000
# 1571           0             0         0      11    2006        WD     385000
# 1701           0             0         0      10    2006        WD     220000
# 1726           0           138         0       3    2006        WD     250764
# 1843           0             0         0       6    2007        WD     240000
# 1854           0             0         0      12    2006        WD     280000
# 1875           0             0         0       6    2007        WD     130000
# 1885           0             0     17000      10    2007        New    183850
# 1964           0           322         0       6    2007        New    591587
#
#        ttl_sf ttl_bath
# 24     2112.0      2.0
# 108    3095.0      2.5
# 337    2871.0      2.0
# 441    2524.0      2.5
# 471    3588.0      2.5
# 616    3820.0      NaN
# 635    1600.0      1.5
# 694    3467.0      3.0
# 745    2434.0      2.0
# 823    4929.0      4.5
# 841    2748.0      2.0
# 913    4550.0      4.0
# 960   11752.0      4.5
# 1052   3027.0      2.0
# 1080   2736.0      2.0
# 1167   2976.0      2.5
# 1542   4077.0      3.5
# 1571   3684.0      2.5
# 1701   4081.0      2.0
# 1726   3282.0      2.0
# 1843   3533.0      3.5
# 1854   3066.0      3.0
# 1875   2034.0      1.0
# 1885  10190.0      4.0
# 1964   4998.0      3.5
#
# [25 rows x 50 columns]

# %%
#dropping two lot_area's over 100,000
# ames.drop(index = [471, 694], inplace = True)

# %%
ordinals = {
            'exter_qual' : {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1 },
            'exter_cond' : {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1 },
            'bsmt_qual'  : {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, 'NA' : 3},
            'bsmt_cond'  : {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1, 'NA' : 3}, 
            'bsmt_exposure' : {'Gd': 5, 'Av': 4, 'Mn': 2, 'No': 1, 'NA': 0},
            'bsmtfin_type_1': {'GLQ': 8, 'ALQ': 6, 'BLQ': 4, 'Rec': 3, 'LwQ': 2, 'Unf': 1 , 'NA': 0},
            'heating_qc': {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1 }, 
            'electrical': {'SBrkr', 'FuseA', 'FuseF', 'FuseP', 'Mix'},
            'kitchen_qual': {'Ex' : 5, 'Gd' : 4, 'TA' : 3, 'Fa' : 2, 'Po' : 1 },
            'functional': {'Typ': 3, 'Min1': 2, 'Min2': 1, 'Mod': 0, 'Maj1': -1, 'Maj2': -2, 'Sev': -3, 'Sal': -4}
           }

# %%
# replace all strings in ordinals with values
for key, value in ordinals.items():
    ames[key].replace(value, inplace = True)

# %%
ames.dtypes.head()
# Out:
# ms_subclass       int64
# ms_zoning        object
# lot_frontage    float64
# lot_area          int64
# lot_config       object
# dtype: object

# %% [markdown]
# # Save Training to CSV

# %%
ames.to_csv('ames1_clean2')

# %% [markdown]
# ________________________________________________

# %% [markdown]
# # Read in Test CSV

# %%
test = pd.read_csv('/Users/jamesopacich/Documents/dsi/projects/project_2/starter_data/test.csv')

# %%
test.shape
# Out:
# (878, 80)

# %%
ames.columns
# Out:
# Index(['ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area', 'lot_config',
#        'neighborhood', 'condition_1', 'condition_2', 'bldg_type',
#        'house_style', 'overall_qual', 'overall_cond', 'year_built',
#        'year_remod/add', 'exterior_1st', 'mas_vnr_type', 'mas_vnr_area',
#        'exter_qual', 'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond',
#        'bsmt_exposure', 'bsmtfin_type_1', 'heating', 'heating_qc',
#        'central_air', 'electrical', 'bedroom_abvgr', 'kitchen_abvgr',
#        'kitchen_qual', 'functional', 'fireplaces', 'garage_type',
#        'garage_yr_blt', 'garage_finish', 'garage_cars', 'paved_drive',
#        'wood_deck_sf', 'open_porch_sf', 'enclosed_porch', '3ssn_porch',
#        'screen_porch', 'misc_val', 'mo_sold', 'yr_sold', 'sale_type',
#        'saleprice', 'ttl_sf', 'ttl_bath'],
#       dtype='object')

# %% [markdown]
# ### change column names in test set

# %%
test.columns = test.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# ### create a sf column to match training df

# %%
test['ttl_sf'] = test['total_bsmt_sf'] + test['gr_liv_area']

# %% [markdown]
# ### create a bath column to match training df

# %%
test['ttl_bath'] = test['full_bath'] + (.5 * test['half_bath']) + test['bsmt_full_bath'] + (.5 * test['bsmt_half_bath'])

# %%
def column_dropper(df, column_list):
    drop_list = []
    for item in df.columns:
        if item not in column_list:
            drop_list.append(item)
    df.drop(columns = drop_list, inplace = True)

# %% [markdown]
# ### drop columns that exist in test-df but not in ames-df

# %%
column_dropper(test, ames.columns)

# %%
test;

# %%
test.shape
# Out:
# (878, 49)

# %%
ames.shape
# Out:
# (2051, 50)

# %% [markdown]
# ### Create Dummies for both Df's

# %%
def dummy_creator(df):
    # a function that takes a df and returns a df with categorical variables dummified. 
    strings = []
    for feature in df.columns:
        if df[feature].dtypes == str or df[feature].dtypes == object:
            strings.append(feature)
    return pd.get_dummies(df, columns = strings, drop_first = True)

# %%
ames_dummy = dummy_creator(ames).copy()

# %%
ames_dummy.shape
# Out:
# (2051, 144)

# %%
test_dummy = dummy_creator(test).copy()

# %%
test_dummy.shape
# Out:
# (878, 157)

# %% [markdown]
# ### Drop dummy columns in test df that are not in training df.

# %%
column_dropper(test_dummy, ames_dummy.columns)

# %%
test_dummy.shape
# Out:
# (878, 120)

# %%
ames_dummy.shape
# Out:
# (2051, 144)

# %% [markdown]
# ### Drop columns in training df that are not in test df

# %%
column_dropper(ames_dummy, test_dummy.columns)

# %%
ames_dummy.shape
# Out:
# (2051, 120)

# %% [markdown]
# ### Add target column back to training df

# %%
ames_dummy['saleprice'] = ames['saleprice']

# %%
ames_dummy.shape
# Out:
# (2051, 121)

# %%
test_dummy.shape
# Out:
# (878, 120)

# %% [markdown]
# ### Convert or Eliminate Leftover Nulls

# %%
def fill_na_mean(df):
    #Cleans float and integer NaNs by replacing with mean
    
    for item in df.columns:
        if df[item].dtypes == float or df[item].dtypes == int:
            df[item].fillna(df[item].mean(), inplace = True)

# %%
fill_na_mean(ames_dummy)

# %% [markdown]
# # Save Files to CSV

# %%
ames_dummy.to_csv('ames1_clean_dummy')

# %%
test_dummy.to_csv('ames1_clean_test_dummy')
